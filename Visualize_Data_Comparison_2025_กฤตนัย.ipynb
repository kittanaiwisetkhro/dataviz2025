# %% [markdown]
# <a href="https://colab.research.google.com/github/kittanaiwisetkhro/dataviz2025/blob/main/Visualize_Data_Comparison_2025_%E0%B8%81%E0%B8%A4%E0%B8%95%E0%B8%99%E0%B8%B1%E0%B8%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os
from datetime import datetime as dt
from datetime import time

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'

# %%
data = pd.read_csv(path)
data.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
data = pd.read_csv(path)
# data = data.iloc[:,1:]
data.head()
# Out:
#             Type                       Date  Part of a policing operation  \
# 0  Person search  2025-01-01T00:35:00+00:00                         False
# 1  Person search  2025-01-01T02:30:00+00:00                         False
# 2  Person search  2025-01-01T02:30:00+00:00                         False
# 3  Person search  2025-01-01T02:30:00+00:00                         False
# 4  Person search  2025-01-01T02:30:00+00:00                         False
#
#    Policing operation   Latitude  Longitude  Gender Age range  \
# 0                 NaN  51.881481   -0.41311    Male     25-34
# 1                 NaN  52.132059   -0.29660    Male     10-17
# 2                 NaN  52.132059   -0.29660    Male     10-17
# 3                 NaN  52.132059   -0.29660  Female     10-17
# 4                 NaN  52.132059   -0.29660    Male     10-17
#
#                               Self-defined ethnicity  \
# 0  Mixed/Multiple ethnic groups - Any other Mixed...
# ...

# %%
data
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
# Group by Officer-defined ethnicity and Object of search, then count the occurrences
ethnicity_case_counts = data.groupby(['Officer-defined ethnicity', 'Object of search']).size().unstack(fill_value=0)

# Display the results
display(ethnicity_case_counts)
# Out:
# Object of search           Article for use in theft  Controlled drugs  \
# Officer-defined ethnicity
# Asian                                             3                69
# Black                                             4                50
# Other                                             5                 3
# White                                            31               138
#
# Object of search           Firearms  Offensive weapons  Stolen goods
# Officer-defined ethnicity
# Asian                             0                  7             2
# Black                             1                  8             1
# Other                             0                  1             0
# White                             1                 19            10

# %%
# Count the occurrences of each ethnicity
ethnicity_counts = data['Officer-defined ethnicity'].value_counts()

# Display the results
display(ethnicity_counts)
# Out:
# Officer-defined ethnicity
# White    199
# Asian     81
# Black     64
# Other      9
# Name: count, dtype: int64

# %%
data['Officer-defined ethnicity'].value_counts()
# Out:
# Officer-defined ethnicity
# White    199
# Asian     81
# Black     64
# Other      9
# Name: count, dtype: int64

# %%
data.groupby('Officer-defined ethnicity')['Type'].count().result_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3875174910.py in <cell line: 0>()
# ----> 1 data.groupby('Officer-defined ethnicity')['Type'].count().result_index()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'result_index'

# %%
ethnicity_counts_groupby = data.groupby('Officer-defined ethnicity')['Type'].count()
display(ethnicity_counts_groupby)
# Out:
# Officer-defined ethnicity
# Asian     81
# Black     64
# Other      9
# White    199
# Name: Type, dtype: int64

# %%
data.groupby('Officer-defined ethnicity')['Type'].count()
# Out:
# Officer-defined ethnicity
# Asian     81
# Black     64
# Other      9
# White    199
# Name: Type, dtype: int64

# %%
compare_police_eth = data.groupby('Officer-defined ethnicity')['Type'].count()
compare_police_eth
# Out:
# Officer-defined ethnicity
# Asian     81
# Black     64
# Other      9
# White    199
# Name: Type, dtype: int64

# %%
compare_police_eth = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %% [markdown]
# ## Bar chart (กราฟแท่ง) (กราฟผลไม้)

# %%
# prompt: สร้าง bar chart เปรียบเทียบปริมาณ sales ทั้งหมดของแต่ละ region ด้วยคำสั้ง plt.bar

import matplotlib.pyplot as plt

# Group data by region and sum sales
region_sales = data.groupby('Region')['Sales'].sum()

# Create the bar chart
plt.bar(region_sales.index, region_sales.values)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2037252087.py in <cell line: 0>()
#       4
#       5 # Group data by region and sum sales
# ----> 6 region_sales = data.groupby('Region')['Sales'].sum()
#       7
#       8 # Create the bar chart
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
# Create the bar chart
plt.bar(compare_police_eth.index, compare_police_eth['Type'])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(compare_police_eth.index, compare_police_eth.values);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2738166727.py in <cell line: 0>()
# ----> 1 plt.bar(compare_police_eth.index, compare_police_eth.values);
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt

# Create the bar chart
plt.bar(compare_police_eth.index, compare_police_eth.values);

# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4172381425.py in <cell line: 0>()
#       2
#       3 # Create the bar chart
# ----> 4 plt.bar(compare_police_eth.index, compare_police_eth.values);
#       5
#       6 # Add labels and title (optional, but good practice)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# ...

# %%
import matplotlib.pyplot as plt

# Create the bar chart with custom colors
colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']  # Define a list of colors
plt.bar(compare_police_eth.index, compare_police_eth.values, color=colors);

# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1862271134.py in <cell line: 0>()
#       3 # Create the bar chart with custom colors
#       4 colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']  # Define a list of colors
# ----> 5 plt.bar(compare_police_eth.index, compare_police_eth.values, color=colors);
#       6
#       7 # Add labels and title (optional, but good practice)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
# ...

# %%
data1 = path1 = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
data2 = path2= '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
data3 = path3 = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-bedfordshire-stop-and-search.csv'
data4 = path4 = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv'

# %%
data1 = pd.read_csv(path1)
data2 = pd.read_csv(path2)
data3 = pd.read_csv(path3)
data4 = pd.read_csv(path4)

# %%
compare_police_eth1 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth2 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth3 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth4 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
compare_police_eth1 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth2 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth3 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth4 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
data['Officer-defined ethnicity'].value_counts()

# %%
data['Officer-defined ethnicity'].value_counts()

# %%
import matplotlib.pyplot as plt

# Create the bar chart with custom colors
colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']  # Define a list of colors
plt.bar(compare_police_eth.index,
        compare_police_eth.values,
        color=colors);

# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# %%
compare_police_eth1 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth2 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth3 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compare_police_eth4 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
import matplotlib.pyplot as plt

# Create the bar chart with custom colors
colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']  # Define a list of colors
plt.bar(compare_police_eth['Officer-defined ethnicity'],
        compare_police_eth['Type'],
        color=colors);

# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Asian'),
#   Text(1, 0, 'Black'),
#   Text(2, 0, 'Other'),
#   Text(3, 0, 'White')])

# %%
import matplotlib.pyplot as plt

# Create the bar chart with custom colors
colors
plt.bar(compare_police_eth['Officer-defined ethnicity'],
        compare_police_eth['Type'],
        color = [[249/255,249/255,0/255],[107/255,77/255,0/255], [107/255,108/255,109/255], [250/255,117/255,117/255]])
         #['skyblue', 'lightcoral', 'lightgreen', 'gold'] )  # Define a list of colors;

# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')

# # Rotate x-axis labels for better readability
# plt.xticks(rotation=45, ha='right')

# %%
compare_police_eth1 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type', ascending=False)
compare_police_eth2 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type', ascending=False)
compare_police_eth3 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type', ascending=False)
compare_police_eth4 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values(by='Type', ascending=False)

# %%
compare_police_eth1 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values('Type')
compare_police_eth2 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values('Type')
compare_police_eth3 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values('Type')
compare_police_eth4 = data.groupby('Officer-defined ethnicity')['Type'].count().reset_index().sort_values('Type')

# %%
import matplotlib.pyplot as plt

# Create the bar chart with custom colors
plt.bar(compare_police_eth1['Officer-defined ethnicity'],
        compare_police_eth1['Type'],
        color = [[249/255,249/255,0/255,0.4],
                [107/255,77/255,0/255,0.4],
                [107/255,108/255,109/255,0.4],
                [250/255,117/255,117/255,0.4]],
      label= 'Jan' )

plt.bar(compare_police_eth2['Officer-defined ethnicity'],
        compare_police_eth2['Type'],
        bottom=compare_police_eth1['Type'],
        color = [[249/255,249/255,0/255,0.5],
                [107/255,77/255,0/255,0.5],
                [107/255,108/255,109/255,0.5],
                [250/255,117/255,117/255,0.5]],
        label= 'Fab' )


plt.bar(compare_police_eth3['Officer-defined ethnicity'],
        compare_police_eth3['Type'],
        bottom=compare_police_eth1['Type'] + compare_police_eth2['Type'],
        color = [[249/255,249/255,0/255,0.6],
                [107/255,77/255,0/255,0.6],
                [107/255,108/255,109/255,0.6],
                [250/255,117/255,117/255,0.6]],
        label= 'Fab' )

plt.bar(compare_police_eth4['Officer-defined ethnicity'],
        compare_police_eth4['Type'],
        bottom=compare_police_eth1['Type'] + compare_police_eth2['Type'] + compare_police_eth3['Type'],
        color = [[249/255,249/255,0/255,0.7],
                [107/255,77/255,0/255,0.7],
                [107/255,108/255,109/255,0.7],
                [250/255,117/255,117/255,0.7]],
        label= 'Mar' )



# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')
plt.legend(title='Legend')

# %%
compare_police_eth1 = data['Officer-defined ethnicity'].value_counts()
compare_police_eth2 = data['Officer-defined ethnicity'].value_counts()
compare_police_eth3 = data['Officer-defined ethnicity'].value_counts()
compare_police_eth4 = data['Officer-defined ethnicity'].value_counts()

# %%
import matplotlib.pyplot as plt

# Create the bar chart with custom colors
plt.bar(compare_police_eth1.index,
        compare_police_eth1.values,
        color = [[249/255,249/255,0/255,0.4],
                [107/255,77/255,0/255,0.4],
                [107/255,108/255,109/255,0.4],
                [250/255,117/255,117/255,0.4]],
      label= 'Jan' )

plt.bar(compare_police_eth1.index,
        compare_police_eth1.values,
        bottom=compare_police_eth1.values,
        color = [[249/255,249/255,0/255,0.5],
                [107/255,77/255,0/255,0.5],
                [107/255,108/255,109/255,0.5],
                [250/255,117/255,117/255,0.5]],
        label= 'Fab' )


plt.bar(compare_police_eth1.index,
        compare_police_eth1.values,
        bottom=compare_police_eth1.values + compare_police_eth2.values,
        color = [[249/255,249/255,0/255,0.6],
                [107/255,77/255,0/255,0.6],
                [107/255,108/255,109/255,0.6],
                [250/255,117/255,117/255,0.6]],
        label= 'Fab' )

plt.bar(compare_police_eth1.index,
        compare_police_eth1.values,
        bottom=compare_police_eth1.values + compare_police_eth2.values + compare_police_eth3.values,
        color = [[249/255,249/255,0/255,0.7],
                [107/255,77/255,0/255,0.7],
                [107/255,108/255,109/255,0.7],
                [250/255,117/255,117/255,0.7]],
        label= 'Mar' )



# Add labels and title (optional, but good practice)
plt.xlabel('Officer-defined Ethnicity')
plt.ylabel('Count')
plt.title('Count of Stop and Search by Officer-Defined Ethnicity')
plt.legend(title='Legend')

# %%
compared_police_eth1 = data1.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth2 = data2.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth3 = data3.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth4 = data4.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
def swap_rows(tab, eth1='Asian', eth2='Other'):
    # Find the indices of 'Asian' and 'Other'
    asian_index = tab[tab['Officer-defined ethnicity'] == eth1].index[0]
    other_index = tab[tab['Officer-defined ethnicity'] == eth2].index[0]

    # Get the rows
    asian_row = tab.loc[asian_index].copy()
    other_row = tab.loc[other_index].copy()

    # Swap the rows
    tab.loc[asian_index] = other_row
    tab.loc[other_index] = asian_row

    return tab

# %%
compared_police_eth1 = swap_rows(compared_police_eth1)
compared_police_eth2 = swap_rows(compared_police_eth2)
compared_police_eth3 = swap_rows(compared_police_eth3)
compared_police_eth4 = swap_rows(compared_police_eth4)

# %%
plt.bar(compared_police_eth1['Officer-defined ethnicity'], compared_police_eth1['Type']
        , color=[[107/255,108/255,109/255,0.4], [107/255,77/255,0,0.4], [249/255,249/255,0,0.4], [250/255,117/255,117/255,0.4]]
        ,label='Jan')
plt.bar(compared_police_eth2['Officer-defined ethnicity'], compared_police_eth2['Type']
        , bottom = compared_police_eth1['Type']
        , color=[[107/255,108/255,109/255,0.5], [107/255,77/255,0,0.5], [249/255,249/255,0,0.5], [250/255,117/255,117/255,0.5]]
        , label='Feb')
plt.bar(compared_police_eth3['Officer-defined ethnicity'], compared_police_eth3['Type']
        , bottom = compared_police_eth1['Type'] + compared_police_eth2['Type']
        , color=[[107/255,108/255,109/255,0.6], [107/255,77/255,0,0.6], [249/255,249/255,0,0.6], [250/255,117/255,117/255,0.6]]
        , label='Mar')
plt.bar(compared_police_eth4['Officer-defined ethnicity'], compared_police_eth4['Type']
        , bottom = compared_police_eth1['Type'] + compared_police_eth2['Type']+ compared_police_eth3['Type']
        , color=[[107/255,108/255,109/255,0.7], [107/255,77/255,0,0.7], [249/255,249/255,0,0.7], [250/255,117/255,117/255,0.7]]
        , label='Apr')
plt.xlabel('Ethnicity')
plt.ylabel('Cases')
plt.legend()
plt.title('Number of Cases open by polices with different ethnicities over Jan-Apr 2025');

# %% [markdown]
# ## Grouped bar chart

# %%
compared_police_eth1 = data1.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth2 = data2.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth3 = data3.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth4 = data4.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
compared_police_eth1 = swap_rows(compared_police_eth1)
compared_police_eth2 = swap_rows(compared_police_eth2)
compared_police_eth3 = swap_rows(compared_police_eth3)
compared_police_eth4 = swap_rows(compared_police_eth4)

# %%
compared_police_eth1
# Out:
#   Officer-defined ethnicity  Type
# 0                     Other     9
# 1                     Black    64
# 2                     Asian    81
# 3                     White   199

# %%
import numpy as np
import matplotlib.pyplot as plt

labels = compared_police_eth1['Officer-defined ethnicity']
cases = compared_police_eth1['Type']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects = ax.bar(x, cases, width)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity')
ax.set_xticks(x)
ax.set_xticklabels(labels)

plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# labels = compared_police_eth1['Officer-defined ethnicity']
# month1_cases = compared_police_eth1['Type']
# month2_cases = compared_police_eth2['Type']

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, compared_police_eth1['Type'], width, label='Month 1 : Jan',color = '#fc9700')
rects2 = ax.bar(x + width/2, compared_police_eth2['Type'], width, label='Month 2 : Feb',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Month 1 vs Month 2)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, compared_police_eth1['Type'], width, label='Month 1 : Jan',color = '#fc9700')
rects2 = ax.bar(x + width/2, compared_police_eth2['Type'], width, label='Month 2 : Feb',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Month 1 vs Month 2)')

ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])

ax.legend();

# %%
x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, compared_police_eth1['Type'], width, label='Month 1 : Jan',color = '#fc9700')
rects2 = ax.bar(x , compared_police_eth2['Type'], width, label='Month 2 : Feb',color = '#19038a')
rects3 = ax.bar(x + width, compared_police_eth3['Type'], width, label='Month 3 : Mar',color = '#FF5733')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Month 1 vs Month 2)')

ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])

ax.legend();

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = compared_police_eth1['Officer-defined ethnicity']
month1_cases = compared_police_eth1['Type']
month2_cases = compared_police_eth2['Type']
month3_cases = compared_police_eth3['Type']
month4_cases = compared_police_eth4['Type']

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width*1.5, month1_cases, width, label='Month 1 : Jan',color = '#fc9700')
rects2 = ax.bar(x - width/2, month2_cases, width, label='Month 2 : Feb',color = '#19038a')
rects3 = ax.bar(x + width/2, month3_cases, width, label='Month 3 : Mar',color = '#FF5733')
# rects4 = ax.bar(x + width*1.5, month4_cases, width, label='Month 4 : Apr',color = '#33FF57')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Months 1-4)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %% [markdown]
# ## Tree map

# %%
data1.head()

# %%
# prompt: plot treemap of the genre

import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify

import squarify

# Assuming 'allGenre' contains the list of genres you want to plot
genre_counts = pd.Series(allGenre).value_counts()

# Create the treemap
squarify.plot(sizes=genre_counts.values, label=genre_counts.index, alpha=.8 )
plt.axis('off')
plt.show()
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2923655633.py in <cell line: 0>()
#       8
#       9 # Assuming 'allGenre' contains the list of genres you want to plot
# ---> 10 genre_counts = pd.Series(allGenre).value_counts()
#      11
#      12 # Create the treemap
#
# NameError: name 'allGenre' is not defined

# %%
object_of_search_counts = data1['Object of search'].value_counts()
object_of_search_counts
# Out:
# Object of search
# Controlled drugs            286
# Article for use in theft     46
# Offensive weapons            37
# Stolen goods                 14
# Firearms                      4
# Name: count, dtype: int64

# %%
# plot Tree map compara=e number of casses based on Object of searc

import squarify
import matplotlib.pyplot as plt

# Group by 'Object of search' and count occurrences
object_of_search_counts = data1['Object of search'].value_counts()

# Create the treemap
plt.figure(figsize=(10, 6))
squarify.plot(sizes=object_of_search_counts.values, label=object_of_search_counts.index, alpha=.8 )
plt.axis('off')
plt.title('Number of Cases by Object of Search')
plt.show()

# %%
# plot Tree map compara=e number of casses based on Object of searc

import squarify
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np



import matplotlib.cm as cm
import numpy as np

n = len(object_of_search_counts)
cmap = cm.get_cmap('Pastel1')  # หรือ 'tab20', 'Pastel1' ฯลฯ
colors = [cmap(i/n) for i in range(n)]

squarify.plot(
    sizes = object_of_search_counts.values,
    label = object_of_search_counts.index,
    color = colors,
    alpha = 0.8
)



# Group by 'Object of search' and count occurrences
object_of_search_counts = data1['Object of search'].value_counts()

# Create the treemap
plt.figure(figsize=(10, 6))
squarify.plot(sizes=object_of_search_counts.values, label=object_of_search_counts.index, alpha=.8 )
plt.axis('off')
plt.title('Number of Cases by Object of Search')
plt.show()
# Out:
# /tmp/ipython-input-1314359338.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Pastel1')  # หรือ 'tab20', 'Pastel1' ฯลฯ

# %% [markdown]
# ## Radar Chart

# %%
data1 = path1 = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-01/2025-01-bedfordshire-stop-and-search.csv'
data2 = path2= '/content/drive/MyDrive/Python&DataViz2025/Data/2025-02/2025-02-bedfordshire-stop-and-search.csv'
data3 = path3 = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-03/2025-03-bedfordshire-stop-and-search.csv'
data4 = path4 = '/content/drive/MyDrive/Python&DataViz2025/Data/2025-04/2025-04-bedfordshire-stop-and-search.csv'

# %%
data1 = pd.read_csv(data1)
data2 = pd.read_csv(data2)
data3 = pd.read_csv(data3)
data4 = pd.read_csv(data4)

# %%
compared_police_eth1 = swap_rows(compared_police_eth1)
compared_police_eth2 = swap_rows(compared_police_eth2)
compared_police_eth3 = swap_rows(compared_police_eth3)
compared_police_eth4 = swap_rows(compared_police_eth4)

# %%
compared_police_eth1
# Out:
#   Officer-defined ethnicity  Type
# 0                     Other     9
# 1                     Black    64
# 2                     Asian    81
# 3                     White   199

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data1
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T00:35:00+00:00
# 1                Person search  2025-01-01T02:30:00+00:00
# 2                Person search  2025-01-01T02:30:00+00:00
# 3                Person search  2025-01-01T02:30:00+00:00
# 4                Person search  2025-01-01T02:30:00+00:00
# ..                         ...                        ...
# 382              Person search  2025-01-31T21:24:00+00:00
# 383              Person search  2025-01-31T21:35:00+00:00
# 384              Person search  2025-01-31T22:15:00+00:00
# 385              Person search  2025-01-31T23:23:00+00:00
# 386  Person and Vehicle search  2025-01-31T23:25:00+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                           False                 NaN  51.881481  -0.413110
# 1                           False                 NaN  52.132059  -0.296600
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

summary = pd.DataFrame([eth_pct_jan])      # 1 แถว, แต่ละคอลัมน์คือเชื้อชาติ
categories = summary.columns.tolist()
values = summary.iloc[0].tolist()
values += values[:1]                   # ปิดวงกลม

angles = [n/float(len(categories))*2*pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(figsize=(8,8), subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, size=11)   # ชื่อรอบวง
plt.yticks(np.arange(0,101,20), [f"{i}%" for i in range(0,101,20)], color="grey")
plt.ylim(0,100)

ax.plot(angles, values, linewidth=1.5, linestyle='solid', label='Officer-defined ethnicity')
ax.fill(angles, values, 'skyblue', alpha=0.4)
ax.set_title('Distribution of Officer-defined Ethnicity', pad=20)
plt.legend(loc='upper right', bbox_to_anchor=(0.1,0.1))
plt.show()

# %%
import pandas as pd
from math import pi
import numpy as np
import matplotlib.pyplot as plt

# --- นับสัดส่วน Officer-defined ethnicity ของ data2 ---
eth_pct_feb = data2['Officer-defined ethnicity'].value_counts(normalize=True) * 100
print(eth_pct_feb)

# --- เตรียมสำหรับ Radar Chart ---
summary = pd.DataFrame([eth_pct_feb])
categories = summary.columns.tolist()
values = summary.iloc[0].tolist()
values += values[:1]

angles = [n/float(len(categories))*2*pi for n in range(len(categories))]
angles += angles[:1]

# --- วาดกราฟ ---
fig, ax = plt.subplots(figsize=(8,8), subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories)
plt.yticks(np.arange(0,101,20), [f"{i}%" for i in range(0,101,20)], color='grey')
plt.ylim(0,100)

ax.plot(angles, values, linewidth=1.5, linestyle='solid', label='Officer-defined ethnicity (Feb)')
ax.fill(angles, values, 'skyblue', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1,0.1))
plt.show()
# Out:
# Officer-defined ethnicity
# White    56.554307
# Asian    23.595506
# Black    18.726592
# Other     1.123596
# Name: proportion, dtype: float64

# %%
import pandas as pd

# คำนวณสัดส่วน (%) ของแต่ละเชื้อชาติ
eth1 = data1['Officer-defined ethnicity'].value_counts(normalize=True) * 100
eth2 = data2['Officer-defined ethnicity'].value_counts(normalize=True) * 100

# รวมให้เป็น DataFrame เดียว (ถ้าบางเชื้อชาติไม่มีในบางเดือนให้เติม 0)
summary = pd.DataFrame({
    'Month1' : eth1,
    'Month2' : eth2
}).fillna(0).T    # .T เพื่อให้แต่ละเดือนเป็นแถว

print(summary)
# Out:
# Officer-defined ethnicity      White      Asian      Black     Other
# Month1                     56.373938  22.946176  18.130312  2.549575
# Month2                     56.554307  23.595506  18.726592  1.123596

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import pi

categories = summary.columns.tolist()
angles = [n/float(len(categories))*2*pi for n in range(len(categories))]
angles += angles[:1]   # ปิดวงกลม



fig, ax = plt.subplots(figsize=(8,8), subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories)
plt.yticks(np.arange(0,101,20), [f"{i}%" for i in range(0,101,20)], color='grey')
plt.ylim(0,100)

# ----- เดือน 1 -----
values1 = summary.loc['Month1'].tolist()
values1 += values1[:1]
ax.plot(angles, values1, linewidth=1.5, linestyle='solid', label='Month 1')
ax.fill(angles, values1, 'skyblue', alpha=0.25)

# ----- เดือน 2 -----
values2 = summary.loc['Month2'].tolist()
values2 += values2[:1]
ax.plot(angles, values2, linewidth=1.5, linestyle='solid', label='Month 2')
ax.fill(angles, values2, 'lightcoral', alpha=0.25)

plt.legend(loc='upper right', bbox_to_anchor=(0.1,0.1))
plt.title('Officer-defined Ethnicity : Month 1 vs Month 2', pad=20)
plt.show()

# %%
import pandas as pd

# นับจำนวนเชื้อชาติแต่ละเดือน
eth_count1 = data1['Officer-defined ethnicity'].value_counts()
eth_count2 = data2['Officer-defined ethnicity'].value_counts()

# รวมตาราง
eth_summary = pd.concat([eth_count1, eth_count2], axis=1, keys=['Month1', 'Month2']).fillna(0)

# เพิ่มรวมทั้งหมด
eth_summary['Total'] = eth_summary['Month1'] + eth_summary['Month2']

print(eth_summary)
# Out:
#                            Month1  Month2  Total
# Officer-defined ethnicity
# White                         199     151    350
# Asian                          81      63    144
# Black                          64      50    114
# Other                           9       3     12

# %% [markdown]
# ### Average Age Range by Ethnicity (Month1 vs Month2)

# %%
# 1. สร้าง Dictionary สำหรับการแปลงค่าเก็บไว้ในตัวแปร
age_replacement_map = {
    '10-17': 14,
    '18-24': 21,
    '25-34': 30,
    'over 34': 34,
    'under 10': 10
}

# 2. ใช้ for loop เพื่อสั่งให้ทำงานกับ DataFrame ทุกตัวที่ต้องการ
for df in [data1, data2, data3, data4]:
    df['Age range'] = df['Age range'].replace(age_replacement_map)

# %%
# 1. สร้าง Dictionary สำหรับการแปลงค่า
age_replacement_map = {
    '10-17': 14,
    '18-24': 21,
    '25-34': 30,
    'over 34': 34,
    'under 10': 10
}

# 2. สร้างฟังก์ชันเพื่อทำการแปลงค่า
def recode_age_range(dataframe):
    dataframe['Age range'] = dataframe['Age range'].replace(age_replacement_map)
    return dataframe

# 3. เรียกใช้ฟังก์ชันกับ DataFrame ที่ต้องการ
data1 = recode_age_range(data1)
data2 = recode_age_range(data2)

# %%
 data1['Age range'].value_counts()
# Out:
# Age range
# 34.0    126
# 21.0     99
# 30.0     80
# 14.0     45
# 10.0      1
# Name: count, dtype: int64

# %%
 data2['Age range'].value_counts()
# Out:
# Age range
# 34.0    102
# 21.0     72
# 30.0     56
# 14.0     28
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# ตัวอย่าง: หาค่าเฉลี่ยอายุของแต่ละเชื้อชาติ
age_by_eth = data1.groupby("Officer-defined ethnicity")["Age range"].mean()

categories = list(age_by_eth.index)
values = age_by_eth.values.flatten().tolist()
values += values[:1]  # วงกลมต้องปิด loop

# สร้างมุมรอบวงกลม
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# plot radar
fig, ax = plt.subplots(figsize=(8,8), subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, color='grey', size=12)

ax.plot(angles, values, linewidth=2, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.4)

plt.title("Average Age (by Officer-defined ethnicity)", size=15, y=1.1)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi


# แปลง Age range เป็น numeric ก่อน
data1['Age range'] = pd.to_numeric(data1['Age range'], errors='coerce')
data2['Age range'] = pd.to_numeric(data2['Age range'], errors='coerce')

# ค่าเฉลี่ยอายุของแต่ละเชื้อชาติ
age_month1 = data1.groupby("Officer-defined ethnicity")["Age range"].mean()
age_month2 = data2.groupby("Officer-defined ethnicity")["Age range"].mean()

# รวมเป็น DataFrame เดียว
df_age = pd.DataFrame({
    "Month1": age_month1,
    "Month2": age_month2
})

# แกนรอบวงกลม
categories = list(df_age.index)
N = len(categories)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

# ค่าแต่ละเดือน
values1 = df_age["Month1"].tolist()
values1 += values1[:1]

values2 = df_age["Month2"].tolist()
values2 += values2[:1]

# สร้าง Radar Chart
fig, ax = plt.subplots(figsize=(8,8), subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], categories, size=12, color="grey")
ax.set_rlabel_position(30)
plt.yticks([10,15,20,25,30,35], ["10","15","20","25","30","35"], color="grey", size=10)
plt.ylim(10,35)

# plot Month1
ax.plot(angles, values1, linewidth=2, linestyle='solid', label="Month1")
ax.fill(angles, values1, 'skyblue', alpha=0.4)

# plot Month2
ax.plot(angles, values2, linewidth=2, linestyle='solid', label="Month2")
ax.fill(angles, values2, 'lightpink', alpha=0.4)

plt.title("Average Age Range by Ethnicity (Month1 vs Month2)", size=14, y=1.1)
plt.legend(loc="upper right", bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# เตรียมข้อมูล (group by officer-defined ethnicity)
eth_age = data.groupby("Officer-defined ethnicity")["Age range"].mean()

categories = eth_age.index.tolist()
values = eth_age.values.tolist()
values += values[:1]  # ปิดวงกลม

N = len(categories)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(polar=True))

# วาดกราฟ
ax.plot(angles, values, linewidth=1, linestyle='solid', label="Average Age")
ax.fill(angles, values, alpha=0.4)

# ตั้งค่าตัวแปรรอบวง
plt.xticks(angles[:-1], categories, size=10)
ax.set_rlabel_position(30)
plt.yticks([10, 20, 30, 40], ["10","20","30","40"], color="grey", size=8)
plt.ylim(0, 40)

plt.title("Average Age range by Officer-defined ethnicity", size=13, y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4053347549.py in <cell line: 0>()
#       5
#       6 # เตรียมข้อมูล (group by officer-defined ethnicity)
# ----> 7 eth_age = data.groupby("Officer-defined ethnicity")["Age range"].mean()
#       8
#       9 categories = eth_age.index.tolist()
#
# AttributeError: 'dict' object has no attribute 'groupby'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import pi

# สร้าง DataFrame จากข้อมูลสรุป
df = pd.DataFrame({
    "Officer-defined ethnicity": ["White", "Asian", "Black", "Other"],
    "Month1": [199, 81, 64, 9],
    "Month2": [151, 63, 50, 3]
})

categories = list(df["Officer-defined ethnicity"])
N = len(categories)

# มุมของแต่ละ category
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]

# เตรียม Figure
fig, ax = plt.subplots(figsize=(6,6), subplot_kw=dict(polar=True))

# วาด Month1
values1 = df["Month1"].tolist()
values1 += values1[:1]
ax.plot(angles, values1, linewidth=1, linestyle='solid', label="Month1")
ax.fill(angles, values1, 'skyblue', alpha=0.4)

# วาด Month2
values2 = df["Month2"].tolist()
values2 += values2[:1]
ax.plot(angles, values2, linewidth=1, linestyle='solid', label="Month2")
ax.fill(angles, values2, 'lightpink', alpha=0.4)

# ตั้งค่ารอบวง
plt.xticks(angles[:-1], categories, size=10)
ax.set_rlabel_position(30)
plt.yticks([50,100,150,200], ["50","100","150","200"], color="grey", size=8)
plt.ylim(0, 220)

plt.title("Stop and Search by Ethnicity (Month1 vs Month2)", size=13, y=1.1)
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))
plt.show()

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data = {'client_id' : ['c1' , 'c2' , 'c3' , 'c4'],
         'cheese' : [2,5,4,3],
         'beer' : [2,1,3,5],
         'chicken' : [5,3,3,4],
        'bread' : [4,3,2,1],
       'coffee' : [2,3,5,3]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df.columns[1:])
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %% [markdown]
# ## การแสดงผล ภาษาไทย

# %%
x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, compared_police_eth1['Type'], width, label='Month 1 : Jan',color = '#fc9700')
rects2 = ax.bar(x , compared_police_eth2['Type'], width, label='Month 2 : Feb',color = '#19038a')
rects3 = ax.bar(x + width, compared_police_eth3['Type'], width, label='Month 3 : Mar',color = '#FF5733')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Month 1 vs Month 2)')

ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])

ax.legend();

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
x = np.arange(len(labels))  # ตำแหน่งของป้ายกำกับ
width = 0.25  # ความกว้างของแท่งกราฟ

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, compared_police_eth1['Type'], width, label='เดือน 1 : มกราคม', color='#fc9700')
rects2 = ax.bar(x, compared_police_eth2['Type'], width, label='เดือน 2 : กุมภาพันธ์', color='#19038a')
rects3 = ax.bar(x + width, compared_police_eth3['Type'], width, label='เดือน 3 : มีนาคม', color='#FF5733')

# เพิ่มข้อความสำหรับแกน ชื่อกราฟ และป้ายกำกับแกน x
ax.set_ylabel('จำนวนคดี')
ax.set_title('จำนวนคดีตามเชื้อชาติที่เจ้าหน้าที่กำหนด (เดือน 1 เทียบเดือน 2)')

ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])  # ถ้าต้องการแปลงชื่อเชื้อชาติเป็นภาษาไทย ต้องแก้ข้อมูลตรงนี้ด้วย

ax.legend();
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 3592 (\N{THAI CHARACTER CHO CHAN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 3635 (\N{THAI CHARACTER SARA AM}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 3609 (\N{THAI CHARACTER NO NU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
x = np.arange(len(labels))  # ตำแหน่งของป้ายกำกับ
width = 0.25  # ความกว้างของแท่งกราฟ

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, compared_police_eth1['Type'], width, label='เดือน 1 : มกราคม', color='#fc9700')
rects2 = ax.bar(x, compared_police_eth2['Type'], width, label='เดือน 2 : กุมภาพันธ์', color='#19038a')
rects3 = ax.bar(x + width, compared_police_eth3['Type'], width, label='เดือน 3 : มีนาคม', color='#FF5733')

# เพิ่มข้อความสำหรับแกน ชื่อกราฟ และป้ายกำกับแกน x
ax.set_ylabel('จำนวนคดี')
ax.set_title('จำนวนคดีตามเชื้อชาติที่เจ้าหน้าที่กำหนด (เดือน 1 เทียบเดือน 2)')

ax.set_xticks(x)
ax.set_xticklabels(compared_police_eth1['Officer-defined ethnicity'])  # ถ้าต้องการแปลงชื่อเชื้อชาติเป็นภาษาไทย ต้องแก้ข้อมูลตรงนี้ด้วย

ax.legend();

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = compared_police_eth1['Officer-defined ethnicity']
month1_cases = compared_police_eth1['Type']
month2_cases = compared_police_eth2['Type']
month3_cases = compared_police_eth3['Type']
month4_cases = compared_police_eth4['Type']

x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width*1.5, month1_cases, width, label='Month 1 : Jan',color = '#fc9700')
rects2 = ax.bar(x - width/2, month2_cases, width, label='Month 2 : Feb',color = '#19038a')
rects3 = ax.bar(x + width/2, month3_cases, width, label='Month 3 : Mar',color = '#FF5733')
rects4 = ax.bar(x + width*1.5, month4_cases, width, label='Month 4 : Apr',color = '#33FF57')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Months 1-4)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = compared_police_eth1['Officer-defined ethnicity']
month1_cases = compared_police_eth1['Type']
month2_cases = compared_police_eth2['Type']
month3_cases = compared_police_eth3['Type']
month4_cases = compared_police_eth4['Type']


x = np.arange(len(labels))  # the label locations
width = 0.2  # the width of the bars

fig, ax = plt.subplots(figsize=(12, 6))
rects1 = ax.bar(x - width*1.5, month1_cases, width, label='Month 1')
rects2 = ax.bar(x - width/2, month2_cases, width, label='Month 2')
rects3 = ax.bar(x + width/2, month3_cases, width, label='Month 3')
rects4 = ax.bar(x + width*1.5, month4_cases, width, label='Month 4')


# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of Cases')
ax.set_title('Number of Cases by Officer-Defined Ethnicity (Months 1-4)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()

# %% [markdown]
# ## Stacked bar chart

# %% [markdown]
# ## Stacked bar chart

# %%
data = pd.read_csv(path)
data.head()

# %%
region_sales

# %%
region_sales.reset_index()['Region']

# %%
region_sales.reset_index().Region

# %%
region_sales.values

# %%
region_sales.index

# %%
# Group data by region and sum sales
region_sales = data.groupby(['Region','Quarter'])['Sales'].sum()
region_sales

# %%
# prompt: สร้าง bar chart เปรียบเทียบปริมาณ sales ทั้งหมดในแต่ละ quarter ของแต่ละ region ด้วย stacked barchart

import matplotlib.pyplot as plt
# Group data by region and quarter, then sum sales
region_quarter_sales = data.groupby(['Region', 'Quarter'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_quarter_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Quarter')

# Show the plot
plt.show()

# %% [markdown]
# ## plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category')

# Show the plot
plt.show()

# %% [markdown]
# การแสดงตัวอักษรภาษาไทยในกราฟ matplotlib
# https://medium.com/@kanyawee.work/%E0%B9%81%E0%B8%AA%E0%B8%94%E0%B8%87%E0%B8%9C%E0%B8%A5%E0%B8%A0%E0%B8%B2%E0%B8%A9%E0%B8%B2%E0%B9%84%E0%B8%97%E0%B8%A2%E0%B9%83%E0%B8%99%E0%B8%81%E0%B8%A3%E0%B8%B2%E0%B8%9F%E0%B8%82%E0%B8%AD%E0%B8%87-matplotlib-%E0%B8%9A%E0%B8%99-google-colab-37210d9a9f31
#
#
# https://colab.research.google.com/drive/1sTdTZx_Cm51mc8OL_QHtehWyO4725sGl#scrollTo=Ak9SbVd5L7U8

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
# prompt: plot stacked barchart ของแต่ละ region โดยดูจาก contribution ของ Price Category

import matplotlib.pyplot as plt
# Group data by region and price category, then sum sales
region_price_category_sales = data.groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the stacked bar chart
region_price_category_sales.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category')

# Show the plot
plt.show()

# %% [markdown]
# ## Plot stacked barchart ด้วย matplotlib

# %%
region_brand_sales = data.groupby(['Region', 'Brand'])['Sales'].sum().unstack()
region_brand_sales

# %%
region_brand_sales['BrandA'].values

# %%
region_brand_sales.index

# %% [markdown]
# ## plot ส่วนแรก

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
#ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่ 2

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width, bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')

ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# ## plot ส่วนที่ 3

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(region_brand_sales.index, region_brand_sales['BrandA'].values, width, label='BrandA',color = '#fc9700')
ax.bar(region_brand_sales.index, region_brand_sales['BrandB'].values, width,
       bottom=region_brand_sales['BrandA'].values, label='BrandB',color = '#19038a')
ax.bar(region_brand_sales.index, region_brand_sales['BrandC'].values, width,
       bottom=region_brand_sales['BrandA'].values + region_brand_sales['BrandB'].values, label='BrandC',color = '#FF5733')


ax.set_ylabel('Total sales')
ax.set_xlabel('Region')
ax.set_title('Total sales by region and brand')
ax.legend()

plt.show()

# %% [markdown]
# # Grouped bar chart (เปรียบเทียบในกลุ่ม)

# %%
# prompt: plot grouped bar chart ของแต่ละ region ในปี 2021 เพื่อเปรียบเทียบ sales ของแต่ละ price category ย้าย legend ออกไปข้างนอกกราฟ ปรับขนาด plot ให้เล็กลง 30%

import matplotlib.pyplot as plt
# Group data by region, year, and price category, then sum sales
region_year_price_category_sales = data[data['Year'] == 2021].groupby(['Region', 'Price Category'])['Sales'].sum().unstack()

# Create the grouped bar chart
ax = region_year_price_category_sales.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Total Sales')
plt.title('Total Sales by Region and Price Category in 2021')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the plot
plt.show()

# %% [markdown]
# ## Plot grouped bar chart ของ หนังอินเดีย โดย แยกกลุ่มตามประเภทหนัง และเปรียบเทียบ rating จาก ความยาวของหนัง

# %%
data_india = pd.read_csv(os.path.join(path,'IMDb Movies India.csv'), encoding='latin-1')
data_india.head()

# %%
data_india = data_india.dropna(subset=['Rating','Duration','Genre'])
data_india = data_india[['Rating','Duration','Genre']]
data_india

# %%
# prompt: แปลงค่าใน column duration เป็น int โดยลบ min ออกและ เปลี่ยนชนิดข้อมูลเป็น integer

# Remove " min" from the 'Duration' column and convert to integer
data_india['Duration'] = data_india['Duration'].str.replace(' min', '').astype(int)

# %%
data_india.describe()

# %%
# prompt: แยกตารางออกเป็นตารางย่อย 5 ตารางสำหรับ genre: drama, action, romance, horror, musical

# Create a dictionary to store the tables
genre_tables = {}

# Define the genres to extract
genres = ['Drama', 'Action', 'Romance', 'Horror', 'Musical']

# Iterate through the genres and create separate tables
for genre in genres:
  genre_tables[genre] = data_india[data_india['Genre'] == genre].copy()

# Access the tables using the genre as the key
# Example:
# drama_table = genre_tables['Drama']

# %%
all_table = pd.concat(genre_tables.values())
all_table

# %%
# prompt: แบ่ง duration ออกเป็น short, medium, long โดย short สั้นกว่า 60 medium 60-90 ที่เหลือ เป็น long

# Function to categorize duration
def categorize_duration(duration):
  if duration < 60:
    return 'short'
  elif 60 <= duration <= 90:
    return 'medium'
  else:
    return 'long'

# Apply the function to create a new column
all_table['Duration Category'] = all_table['Duration'].apply(categorize_duration)
all_table

# %%
all_table.groupby(['Genre','Duration Category'])['Rating'].mean()

# %%
india_bar_data = all_table.groupby(['Genre','Duration Category'])['Rating'].mean().unstack()

# %%
india_bar_data

# %%
ax = india_bar_data.plot(kind='bar', figsize=(8, 6), width=0.8)

# Add labels and title
plt.xlabel('Genre')
plt.ylabel('Rating')
plt.title('หนังอินเดีย โดย แยกกลุ่มตามประเภทหนัง และเปรียบเทียบ rating จาก ความยาวของหนัง')

# Move legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Adjust plot size
plt.gcf().set_size_inches(plt.gcf().get_size_inches() * 0.7)

# Show the plot
plt.show()

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')
plt.title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน');

# %%
plt.bar([1,2,3,4,5,6,7],[data[data['search_timestamp'].dt.dayofweek == 0].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 1].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 2].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 3].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 4].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 5].shape[0],
                         data[data['search_timestamp'].dt.dayofweek == 6].shape[0]
                         ],tick_label=['Mon','Tue','Wed','Thu','Fri','Sat','Sun'])
plt.xlabel('Days')
plt.ylabel('Number of Requests')

# %% [markdown]
# ## Grouped bar chart
#
# https://matplotlib.org/stable/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %% [markdown]
# แสดงปริมาณคนเข้าเว๊ปในแต่ละวัน โดยเปรียบเทียบช่วงเวลา 11:00-12:00 กับ 23:00-24:00

# %%
compared_police_eth1 = data1.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth2 = data2.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth3 = data3.groupby('Officer-defined ethnicity')['Type'].count().reset_index()
compared_police_eth4 = data4.groupby('Officer-defined ethnicity')['Type'].count().reset_index()

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)
& (data['search_timestamp'].dt.time < time(hour=12))
& (data['search_timestamp'].dt.time >= time(hour=11))].shape[0]  # monday 11:00-12:00

# %%
b4lunch = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time < time(hour=12))&(data['search_timestamp'].dt.time >= time(hour=11))].shape[0]
                         ]

# %%
b4lunch

# %%
data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]

# %%
b4midnight = [data[(data['search_timestamp'].dt.dayofweek == 0)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 1)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 2)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 3)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 4)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 5)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0],
           data[(data['search_timestamp'].dt.dayofweek == 6)&(data['search_timestamp'].dt.time >= time(hour=23))].shape[0]
                         ]
b4midnight

# %%
labels = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
import numpy as np

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, b4lunch, width, label='lunch time',color = '#fc9700')
rects2 = ax.bar(x + width/2, b4midnight, width, label='midnight',color = '#19038a')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน เปรียบเทียบ 2 ช่วงเวลา')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend();

# %% [markdown]
# ## Stacked bar chart

# %%
import matplotlib.pyplot as plt

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.bar(labels, b4midnight, width, bottom=b4lunch, label='before midnight',color = '#19038a')

ax.set_ylabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %%
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.barh(labels, b4lunch, width, label='before lunch',color = '#fc9700')
ax.barh(labels, b4midnight, width, left=b4lunch, label='before midnight',color = '#19038a')

ax.set_xlabel('number of requests')
ax.set_title('ปริมาณคนเข้าใช้ Wongnai.com ในแต่ละวัน โดยคิดจาก 2 ช่วงเวลา')
ax.legend()

plt.show()

# %% [markdown]
# ## [เช็คชื่อ] โดยให้วาด Bar chart ที่เปรียบเทียบปริมาณคนใช้งาน Wongnai.com สองช่วงเวลา โดยให้กราฟแสดงสัดส่วนของปริมาณคนใช้งานในแต่ละวันด้วย

# %% [markdown]
# ## Histogram

# %% [markdown]
# ## กราฟแสดงความถี่ของข้อมูล

# %% [markdown]
# ตัวอย่างข้อมูลที่ random มาจาก normal distribution ที่มี mean = 100  และ stdev = 15

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(2024)

mu, sigma = 100, 15
X = mu + sigma * np.random.randn(10000)

plt.hist(X, 50, facecolor = 'violet', alpha = 0.75)

# %% [markdown]
# ## ทดสอบกับข้อมูลหนังอินเดีย

# %%
data_india = pd.read_csv(os.path.join(path,'IMDb Movies India.csv'), encoding='latin-1')
data_india.head()

# %%
len(set(data_india.dropna(subset=['Genre'])['Genre']))

# %%
plt.hist(data_india.dropna(subset=['Genre'])['Genre'],bins = len(set(data_india.dropna(subset=['Genre'])['Genre'])))
plt.xticks(rotation='vertical');

# %%
data_india['Genre'].str.split(',', expand=True)

# %%
data_india = data_india.dropna(subset=['Genre'])

# %%
# prompt: split value in column genre by ',' and make more column for each of those

import pandas as pd
# Split the 'Genre' column by ',' and create new columns
genre_split = data_india['Genre'].str.split(',', expand=True)

# Rename the new columns
genre_split.columns = ['Genre1', 'Genre2', 'Genre3']

# Concatenate the new columns with the original DataFrame
data_india = pd.concat([data_india, genre_split], axis=1)

# Display the updated DataFrame
data_india.head()

# %%
# prompt: delete space in the value in Genre1 Genre2 Genre3

for col in ['Genre1', 'Genre2', 'Genre3']:
  data_india[col] = data_india[col].str.strip() if data_india[col].dtype == 'object' else data_india[col]

# %%
allGenre = list(data_india['Genre1'])+list(data_india['Genre2'])+list(data_india['Genre3'])

# %%
len(set(allGenre))

# %%
allGenre[-20:]

# %%
allGenre[:13]

# %%
# prompt: delete all None from the allGenre list

allGenre = [x for x in allGenre if x is not None]

# %%
plt.hist(allGenre,bins = len(set(allGenre)))
plt.xticks(rotation='vertical');

# %% [markdown]
# # Quiz15 หาพระเอก-นางเอก ที่มักจะแสดงคู่กัน ด้วย Histogram (พระเอก actor1, นางเอก actor2)

# %% [markdown]
# ## Tree map

# %%
# prompt: plot treemap of the genre

import pandas as pd
import matplotlib.pyplot as plt
# !pip install squarify

import squarify

# Assuming 'allGenre' contains the list of genres you want to plot
genre_counts = pd.Series(allGenre).value_counts()

# Create the treemap
squarify.plot(sizes=genre_counts.values, label=genre_counts.index, alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ## Radar Chart

# %%
import numpy as np
import pandas as pd  #import pandas มาเพราะข้อมูลจะเกี่ยวกับตาราง
import matplotlib.pyplot as plt
from math import pi #import math มาเนื่องจากเกี่ยวกับวงกลมนำมาใช้เพื่อดึงค่าพาย

# %%
data = {'client_id' : ['c1' , 'c2' , 'c3' , 'c4'],
         'cheese' : [2,5,4,3],
         'beer' : [2,1,3,5],
         'chicken' : [5,3,3,4],
        'bread' : [4,3,2,1],
       'coffee' : [2,3,5,3]}
df = pd.DataFrame.from_dict(data)
df
# Out:
#   client_id  cheese  beer  chicken  bread  coffee
# 0        c1       2     2        5      4       2
# 1        c2       5     1        3      3       3
# 2        c3       4     3        3      2       5
# 3        c4       3     5        4      1       3

# %%
categories = list(df.columns[1:])
categories
# Out:
# ['cheese', 'beer', 'chicken', 'bread', 'coffee']

# %%
values = df.iloc[:,1:].mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

ax.plot(angles, values, linewidth=1, linestyle='solid' , color = '#ea3033') #เส้นกราฟ
ax.fill(angles, values, 'lightpink', alpha=0.5) #พื้นที่

# %%
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=12)
plt.yticks(np.arange(1, 6), ['1', '2', '3', '4', '5'],
           color='grey', size=12)

plt.ylim(0, 5)
ax.set_rlabel_position(30)

# part 1
val_c1 = df.loc[0].drop('client_id').values.flatten().tolist()
val_c1 += val_c1[:1]
ax.plot(angles, val_c1, linewidth=1,
        linestyle='solid', label='Client c1')
ax.fill(angles, val_c1, 'skyblue', alpha=0.4)

# part 2
val_c2=df.loc[1].drop('client_id').values.flatten().tolist()
val_c2 += val_c2[:1]
ax.plot(angles, val_c2, linewidth=1,
        linestyle='solid', label='Client c2')
ax.fill(angles, val_c2, 'lightpink', alpha=0.4)

plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# %% [markdown]
# # HW9 present radar chart data india
